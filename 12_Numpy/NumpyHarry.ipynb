# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

# %%
myarr = np.array([3,6,32,7])

# %%
# Here we the values of int that can be stored are [-128,127]
# as out of eight bytes 1 byte(sign) and then 7 bytes are for storing numbers which can store a 128 numbers
# which can combined with [+,-] total 256 different numbers are possible
myarr = np.array([-128,6,3299999,127],np.int8)
myarr
# Out:
# array([-128,    6,  -97,  127], dtype=int8)

# %%
2**7
# Out:
# 128

# %%
3299999%128
# Out:
# 31
