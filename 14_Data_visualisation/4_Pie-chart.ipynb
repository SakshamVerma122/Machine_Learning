# %% [markdown]
# ### Pie chart

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.pie?

# %%
subjects = "Maths","Chem","Physics","English"
marks = 20,10,15,5

plt.pie(marks,labels = subjects,explode=(0,0,0.1,0),colors = ("orange","green","brown","blue"),autopct="%1.1f%%",startangle=90,shadow=True)
# explode=(Contains radius)
# Highlights a particular wedge by taking it out of the others
# autopct--> gives percentage
# The default startangle is 0 .In this example sets startangle = 90 such that everything is rotated counter-clockwise by 90 degrees.

ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-e3c8c4238473> in <module>
#       8 # The default startangle is 0 .In this example sets startangle = 90 such that everything is rotated counter-clockwise by 90 degrees.
#       9
# ---> 10 ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#
# NameError: name 'ax1' is not defined

# %%
plt.
