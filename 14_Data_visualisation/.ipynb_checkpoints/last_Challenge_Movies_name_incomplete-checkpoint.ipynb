# %% [markdown]
# ### Data Visualisation Challenge
# Given a Movie Dataset , your task is to make a visualisation that
# * Plots the Length of Movie Tiltle Names on X-Axis
# * Frequency Counts on Y-axis i.e. Number of Movies having 'x' characters in their title

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(r"E:\Coding_blocks_machine_learning\22. Data Visualisation\IMDb movies.csv")
# Out:
# C:\Users\saksh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
dataset
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# ...

# %%
dataset["Name_length"] = [len(name) for name in dataset["title"]]

# %%
dataset[["title","Name_length"]]
# Out:
#                                 title  Name_length
# 0                          Miss Jerry           10
# 1         The Story of the Kelly Gang           27
# 2                      Den sorte drøm           14
# 3                           Cleopatra            9
# 4                           L'Inferno            9
# ...                               ...          ...
# 85850                         Le lion            7
# 85851  De Beentjes van Sint-Hildegard           30
# 85852       Padmavyuhathile Abhimanyu           25
# 85853               Sokagin Çocuklari           17
# 85854      La vida sense la Sara Amat           26
#
# [85855 rows x 2 columns]

# %%
plt.hist(dataset["Name_length"],bins=50,range=(0,75))
# Out:
# (array([3.300e+01, 8.100e+01, 1.743e+03, 2.170e+03, 5.888e+03, 3.586e+03,
#         7.751e+03, 4.098e+03, 8.563e+03, 4.517e+03, 8.658e+03, 4.070e+03,
#         7.511e+03, 3.308e+03, 5.463e+03, 2.232e+03, 3.608e+03, 1.439e+03,
#         2.435e+03, 1.096e+03, 1.756e+03, 7.670e+02, 1.216e+03, 5.060e+02,
#         8.110e+02, 3.100e+02, 5.380e+02, 1.860e+02, 3.430e+02, 1.420e+02,
#         2.430e+02, 8.900e+01, 1.730e+02, 6.400e+01, 8.800e+01, 4.000e+01,
#         6.300e+01, 2.800e+01, 5.000e+01, 2.500e+01, 2.700e+01, 1.700e+01,
#         2.400e+01, 6.000e+00, 1.500e+01, 7.000e+00, 1.000e+01, 7.000e+00,
#         1.600e+01, 5.000e+00]),
#  array([ 0. ,  1.5,  3. ,  4.5,  6. ,  7.5,  9. , 10.5, 12. , 13.5, 15. ,
#         16.5, 18. , 19.5, 21. , 22.5, 24. , 25.5, 27. , 28.5, 30. , 31.5,
#         33. , 34.5, 36. , 37.5, 39. , 40.5, 42. , 43.5, 45. , 46.5, 48. ,
#         49.5, 51. , 52.5, 54. , 55.5, 57. , 58.5, 60. , 61.5, 63. , 64.5,
#         66. , 67.5, 69. , 70.5, 72. , 73.5, 75. ]),
# ...

# %%
plt.hist?
