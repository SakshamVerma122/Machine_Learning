# %% [markdown]
# ### Bar-graph

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.bar?

# %%
# align='edge' -> Align the left edges of the bars with the *x* positions.
# align='center' -> Center the base on the *x* positions.
plt.bar([0,1,2],[10,20,15],align='edge')
plt.show()
plt.bar([0,1,2],[10,20,15],align='center')
plt.show()

# %%
x_coordinates = np.array([0,1,2])

plt.bar(x_coordinates,[10,20,15],width=0.25)
plt.bar(x_coordinates+0.25,[20,10,12],width=0.25)

# important by default the width of each bar graph is 1
# Out:
# <BarContainer object of 3 artists>

# %%
plt.style.use("dark_background")
x_coordinates = np.array([0,1,2])*2

plt.bar(x_coordinates,[10,20,15],width=0.5,label="Current_year",tick_label=["Gold","Platinum","Silver"])
plt.bar(x_coordinates+0.5,[20,10,12],width=0.5,label="Next_year",color = "red")

plt.title("Metal price comparison")

plt.xlabel("Metals")
plt.ylabel("Price")

plt.legend()
# important by default the width of each bar graph is 1

# adding limit to y_axis
plt.ylim(0,40)
# Out:
# (0.0, 40.0)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']
